# %%
import pandas as pd

df_csv = pd.read_csv('/content/1_The_Schedule_of_GE_to_Lok_Sabha_ii_0.csv')

df_csv
# Out:
#     Sr. No.  No. Of Phases          States and Union Territories
# 0         1              1                        Andhra Pradesh
# 1         2              1                     Arunachal Pradesh
# 2         3              3                                 Assam
# 3         4              7                                 Bihar
# 4         5              1                                   Goa
# 5         6              1                               Gujarat
# 6         7              1                               Haryana
# 7         8              1                      Himachal Pradesh
# 8         9              2                             Karnataka
# 9        10              1                                Kerala
# 10       11              4                        Madhya Pradesh
# 11       12              5                           Maharashtra
# 12       13              2                               Manipur
# ...

# %%
df_csv.head()
# Out:
#    Sr. No.  No. Of Phases States and Union Territories
# 0        1              1               Andhra Pradesh
# 1        2              1            Arunachal Pradesh
# 2        3              3                        Assam
# 3        4              7                        Bihar
# 4        5              1                          Goa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Sr. No.'].plot(kind='hist', bins=20, title='Sr. No.')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['No. Of Phases'].plot(kind='hist', bins=20, title='No. Of Phases')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sr. No.                       36 non-null     int64
#  1   No. Of Phases                 36 non-null     int64
#  2   States and Union Territories  36 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 996.0+ bytes

# %%
df_csv.describe()
# Out:
#          Sr. No.  No. Of Phases
# count  36.000000      36.000000
# mean   18.500000       2.194444
# std    10.535654       1.909666
# min     1.000000       1.000000
# 25%     9.750000       1.000000
# 50%    18.500000       1.000000
# 75%    27.250000       3.000000
# max    36.000000       7.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Sr. No.'].plot(kind='hist', bins=20, title='Sr. No.')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['No. Of Phases'].plot(kind='hist', bins=20, title='No. Of Phases')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...
